# %%
import pandas as pd
from pathlib import Path

csv_path = ("/Users/thehalpins/FinTech_instructionals/python-homework/PyBank/people.csv")

people_csv = pd.read_csv(csv_path)
people_csv.head()
# Out:
#   first_name   last_name gender  age             company_name  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas      M   47       Cap Gemini America
# 2     France     Andrade      M   42      Elliott, John W Esq
# 3    Ulysses   Mcwalters      M   45           Mcmahan, Ben L
# 4     Tyisha      Veness      F   37           Champagne Room
#
#              address                            city           county  \
# 0       14 Taylor St               St. Stephens Ward             Kent
# 1        5 Binney St                      Abbey Ward  Buckinghamshire
# 2       8 Moor Place  East Southbourne and Tuckton W      Bournemouth
# 3      505 Exeter Rd              Hawerby cum Beesby     Lincolnshire
# 4  5396 Forth Street      Greets Green and Lyng Ward    West Midlands
#
#      postal        phone1        phone2                       email  \
# 0   CT2 7PP  01835-703597  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
people_csv.iloc(0)

# %%
people_csv.head()
# Out:
#   first_name   last_name gender  age             company_name  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas      M   47       Cap Gemini America
# 2     France     Andrade      M   42      Elliott, John W Esq
# 3    Ulysses   Mcwalters      M   45           Mcmahan, Ben L
# 4     Tyisha      Veness      F   37           Champagne Room
#
#              address                            city           county  \
# 0       14 Taylor St               St. Stephens Ward             Kent
# 1        5 Binney St                      Abbey Ward  Buckinghamshire
# 2       8 Moor Place  East Southbourne and Tuckton W      Bournemouth
# 3      505 Exeter Rd              Hawerby cum Beesby     Lincolnshire
# 4  5396 Forth Street      Greets Green and Lyng Ward    West Midlands
#
#      postal        phone1        phone2                       email  \
# 0   CT2 7PP  01835-703597  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
people_csv.iloc[-10]
# Out:
# first_name                               Rosita
# last_name                             Ausdemore
# gender                                        F
# age                                          35
# company_name                  Jurdem, Scott Esq
# address                    8 Heathfield St #657
# city                                   Hailsham
# county                              East Sussex
# postal                                 BN27 1AJ
# phone1                             01273-236188
# phone2                             01997-765432
# email                    rausdemore@hotmail.com
# web             http://www.jurdemscottesq.co.uk
# Name: 490, dtype: object

# %%
#returns the values of the column represented by the '11' ie. column number
people_csv.iloc[:,11].head()
# Out:
# 0       atomkiewicz@hotmail.com
# 1      evan.zigomalas@gmail.com
# 2    france.andrade@hotmail.com
# 3           ulysses@hotmail.com
# 4     tyisha.veness@hotmail.com
# Name: email, dtype: object

# %%
people_csv.iloc[0:4:5]
# Out:
#   first_name   last_name gender  age             company_name       address  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                 city county   postal        phone1        phone2  \
# 0  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                      email                                   web
# 0  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk

# %%
people_csv.iloc[0, people_csv.columns.get_loc("first_name")] = "Arya"

# %%
people_csv.iloc[0]
# Out:
# first_name                                      Arya
# last_name                                 Tomkiewicz
# gender                                             F
# age                                               54
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
people_csv[people_csv["gender"] == "M"].head()
# Out:
#    first_name  last_name gender  age                   company_name  \
# 1        Evan  Zigomalas      M   47             Cap Gemini America
# 2      France    Andrade      M   42            Elliott, John W Esq
# 3     Ulysses  Mcwalters      M   45                 Mcmahan, Ben L
# 5        Eric      Rampy      M   28        Thompson, Michael C Esq
# 14     Rueben  Gastellum      M   29  Industrial Engineering Assocs
#
#           address                            city            county    postal  \
# 1     5 Binney St                      Abbey Ward   Buckinghamshire  HP11 2AX
# 2    8 Moor Place  East Southbourne and Tuckton W       Bournemouth   BH6 3BE
# 3   505 Exeter Rd              Hawerby cum Beesby      Lincolnshire  DN36 5RP
# 5    9472 Lind St                      Desborough  Northamptonshire  NN14 2GH
# 14   4 Forrest St               Weston-Super-Mare    North Somerset  BS23 3HG
#
#           phone1        phone2                             email  \
# ...

# %%
people_csv.iloc[0, pe
