# %%
#02 column manipulation


import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

people_csv = Path("people.csv")
people_csv = pd.read_csv(people_csv,index_col=0)
people_csv.head()
# Out:
#              last_name gender  age             company_name  \
# first_name
# Aleshia     Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc
# Evan         Zigomalas      M   47       Cap Gemini America
# France         Andrade      M   42      Elliott, John W Esq
# Ulysses      Mcwalters      M   45           Mcmahan, Ben L
# Tyisha          Veness      F   37           Champagne Room
#
#                       address                            city  \
# first_name
# Aleshia          14 Taylor St               St. Stephens Ward
# Evan              5 Binney St                      Abbey Ward
# France           8 Moor Place  East Southbourne and Tuckton W
# Ulysses         505 Exeter Rd              Hawerby cum Beesby
# Tyisha      5396 Forth Street      Greets Green and Lyng Ward
#
#                      county    postal        phone1        phone2  \
# first_name
# Aleshia                Kent   CT2 7PP  01835-703597  01944-369967
# ...

# %%
# Use the `columns` attribute to output the column names

data_top = people_csv.head()
data_top

for col in data_top.columns:
    print(col)
# Out:
# last_name
# gender
# age
# company_name
# address
# city
# county
# postal
# phone1
# phone2
# email
# web

# %%
list(people_csv.columns)
# Out:
# ['last_name',
#  'gender',
#  'age',
#  'company_name',
#  'address',
#  'city',
#  'county',
#  'postal',
#  'phone1',
#  'phone2',
#  'email',
#  'web']

# %%
#View Column Data Types
list (people_csv.dtypes)
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O')]

# %%
# 6. Rename Columns Using List

# Set the `columns` attribute to a new list of column names
people_csv.columns = ['person_id', 'first_name', 'last_name', 'email', 'gender', 'uni','occupation','county',
 'postal',
 'phone1',
 'phone2',
 'web']
people_csv.head()
# Out:
#              person_id first_name  last_name                    email  \
# first_name
# Aleshia     Tomkiewicz          F         54  Alan D Rosenburg Cpa Pc
# Evan         Zigomalas          M         47       Cap Gemini America
# France         Andrade          M         42      Elliott, John W Esq
# Ulysses      Mcwalters          M         45           Mcmahan, Ben L
# Tyisha          Veness          F         37           Champagne Room
#
#                        gender                             uni  \
# first_name
# Aleshia          14 Taylor St               St. Stephens Ward
# Evan              5 Binney St                      Abbey Ward
# France           8 Moor Place  East Southbourne and Tuckton W
# Ulysses         505 Exeter Rd              Hawerby cum Beesby
# Tyisha      5396 Forth Street      Greets Green and Lyng Ward
#
#                  occupation    county        postal        phone1  \
# first_name
# ...

# %%
# save modified data frame to new csv

people_csv.to_csv("resources.csv")
